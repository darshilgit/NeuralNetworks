# %% [markdown]
# Question from Chapter 4:
#
# Why is the weight vector always orthogonal to the decision boundary?

# %% [markdown]
# Question from Chapter 5:
#
# ![New%20Doc%202018-09-26%2019.54.14.jpg](attachment:New%20Doc%202018-09-26%2019.54.14.jpg)
